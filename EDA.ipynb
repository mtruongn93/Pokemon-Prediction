# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import StandardScaler, MultiLabelBinarizer, LabelBinarizer
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.base import TransformerMixin, BaseEstimator
import numpy as np
import re
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# # Data Cleaning

# %%
data = pd.read_csv("data/pokemon.csv", keep_default_na = False)
train = pd.read_csv("data/train.csv")
test = pd.read_csv("test.csv")

# %%
data.head()
# Out:
#    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2     Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3    Venusaur  Grass  Poison  80      82       83      100      100     80
# 3  5  Charmander   Fire          39      52       43       60       50     65
# 4  6  Charmeleon   Fire          58      64       58       80       65     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %% [markdown]
# We are going to combine types columns into 1 column so that we can use **MultiLabelBinarizer** later

# %%
data["type"] = [[data["Type 1"][i], data["Type 2"][i]]
                for i in range(0, len(data))]

# %%
data.drop(["Type 1", "Type 2", "Generation", "Legendary"], axis = 1, inplace=True)

# %%
data.head()
# Out:
#    #        Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1   Bulbasaur  45      49       49       65       65     45
# 1  2     Ivysaur  60      62       63       80       80     60
# 2  3    Venusaur  80      82       83      100      100     80
# 3  5  Charmander  39      52       43       60       50     65
# 4  6  Charmeleon  58      64       58       80       65     80
#
#               type
# 0  [Grass, Poison]
# 1  [Grass, Poison]
# 2  [Grass, Poison]
# 3         [Fire, ]
# 4         [Fire, ]

# %% [markdown]
# Let's look at our training dataset

# %%
train.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0              5              49       5
# 1            119               5       5
# 2            130              52     130
# 3            123             139     139
# 4            166             108     166

# %%
train.shape
# Out:
# (1402, 3)

# %% [markdown]
# To make things easier to predict, we will change the **Winner** column to 1 if **First_pokemon** wins, else 0. This eventually becomes a **Classification** problem.

# %%
train["Winner"] = [1 if train["First_pokemon"][i] == train["Winner"][i] else 0 for i in range(0,len(train))]

# %% [markdown]
# We are going to generate more rows which are just the reverse of **First_pokemon** and **Second_pokemon** column the original data. Hence, the values in the **Winner** column will also change.

# %%
train_reverse = train.copy()

# %%
train_reverse[["First_pokemon","Second_pokemon"]] = train_reverse[["Second_pokemon","First_pokemon"]]

# %%
train_reverse["Winner"] = 1 - train["Winner"]

# %%
train = pd.concat([train, train_reverse], axis = 0)

# %%
train.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0              5              49       1
# 1            119               5       0
# 2            130              52       1
# 3            123             139       0
# 4            166             108       1

# %%
train.shape
# Out:
# (2804, 3)

# %% [markdown]
# The next thing that we need to do is to map all the stats corresponing to **First_pokemon** and **Second_pokemon** to a same DataFrame

# %%
first_step = pd.merge(train,data,left_on="First_pokemon", right_on="#", how = "left")

# %%
second_step = pd.merge(first_step,data,left_on="Second_pokemon", right_on="#", how = "left")

# %%
second_step.drop(["First_pokemon","Second_pokemon","#_x", "Name_x", "#_y", "Name_y"], axis = 1, inplace=True)

# %%
train = second_step.copy()

# %%
train
# Out:
#       Winner  HP_x  Attack_x  Defense_x  Sp. Atk_x  Sp. Def_x  Speed_x  \
# 0          1    39        52         43         60         50       65
# 1          0    65        90        120         85         70       60
# 2          1    30        45         55         70         55       85
# 3          0    65        55        115        100         40       60
# 4          1   100       100        100        100        100      100
# 5          1    80        82         78         95         80       85
# 6          1    70       110         80         55         80      105
# 7          1    90        92         87         75         85       76
# 8          1    50       105         79         35        110       76
# 9          1    52        65         55         58         62       60
# 10         1    30        45         55         70         55       85
# 11         0    60        55         50         40         55       45
# 12         1    80       105         65         60         75      130
# 13         0   250         5          5         35        105       50
# 14         0    95        95         85        125         65       55
# 15         1    65       100         70         80         80      105
# 16         0    65        90        120         85         70       60
# 17         1    65       125        100         55         70       85
# 18         0    70        45         48         60         65       35
# 19         1    78        84         78        109         85      100
# 20         0    40        65         95         60         45       35
# 21         0    30        65        100         45         25       40
# 22         1    65        95         57        100         85       93
# 23         1    81       102         77         85         75       85
# 24         1    60       110         70         60         60      100
# 25         1   160       110         65         65        110       30
# 26         1    65        95         57        100         85       93
# 27         0    65        50         35        115         95       95
# 28         1    75       100        110         45         55       65
# 29         1    58        64         58         80         65       80
# ...      ...   ...       ...        ...        ...        ...      ...
# 2774       0   250         5          5         35        105       50
# 2775       1    25        20         15        105         55       90
# 2776       0    50        50         95         40         50       35
# 2777       0    40        45         35         30         40       55
# 2778       0    65       130         60         95        110       65
# 2779       1    45        67         60         35         50       63
# 2780       1    65       100         70         80         80      105
# 2781       0    70        45         48         60         65       35
# 2782       1    50       105         79         35        110       76
# 2783       0    35        40        100         90         55       35
# 2784       1    95       125         79         60        100       81
# 2785       0   105       130        120         45         45       40
# 2786       1    40        30         50         55         55      100
# 2787       1    50        50         95         40         50       35
# 2788       0    35        70         55         45         55       25
# 2789       1    60       115        105         65         70       80
# 2790       0    65        55        115        100         40       60
# 2791       1   106       110         90        154         90      130
# 2792       0    95       125         79         60        100       81
# 2793       1    55        81         60         50         70       97
# 2794       1    60       115        105         65         70       80
# 2795       1    35        45        160         30         45       70
# 2796       0    70        45         48         60         65       35
# 2797       0    70        60        125        115         70       55
# 2798       0    60        40         80         60         45       40
# 2799       0    90        65         65         40         40       15
# 2800       1    59        63         80         65         80       58
# 2801       1    90       100         90        125         85       90
# 2802       1    80       100         70         50         60       45
# 2803       0    30       105         90         25         25       50
#
#                 type_x  HP_y  Attack_y  Defense_y  Sp. Atk_y  Sp. Def_y  \
# 0             [Fire, ]    45        50         55         75         65
# 1           [Poison, ]    39        52         43         60         50
# 2            [Water, ]    35        70         55         45         55
# 3            [Grass, ]    75       100         95         40         70
# 4          [Psychic, ]    55       130        115         50         50
# 5            [Water, ]    70        45         48         60         65
# 6        [Bug, Flying]    46        57         40         40         40
# 7     [Poison, Ground]    60        62         63         80         80
# 8         [Fighting, ]    70        80         50         35         35
# 9     [Normal, Flying]    90        55         75         60         75
# 10           [Water, ]    35        60         44         40         54
# 11       [Bug, Poison]   106       110         90        154         90
# 12      [Rock, Flying]    55        50         45        135         95
# 13          [Normal, ]    50       105         79         35        110
# 14    [Grass, Psychic]    40        45         35         30         40
# 15            [Fire, ]    40        40         35         50        100
# 16          [Poison, ]    30        40         70         70         25
# 17             [Bug, ]    80        82         83        100        100
# 18           [Fairy, ]    59        63         80         65         80
# 19      [Fire, Flying]    60        95         80         60         80
# 20          [Poison, ]    60        80        110         50         80
# 21           [Water, ]    50        85         55         65         65
# 22            [Fire, ]    50        52         48         65         50
# 23    [Poison, Ground]    30        56         35         25         35
# 24    [Normal, Flying]    65        65         65         50         50
# 25          [Normal, ]    65        50         35        115         95
# 26            [Fire, ]    55       130        115         50         50
# 27      [Ice, Psychic]    70       110         80         55         80
# 28          [Ground, ]    65        90         50         85         45
# 29            [Fire, ]    40        45         35         30         40
# ...                ...   ...       ...        ...        ...        ...
# 2774        [Normal, ]    65       130         60         95        110
# 2775       [Psychic, ]    75        80         70         65         75
# 2776        [Ground, ]   130        85         80         85         95
# 2777  [Poison, Flying]    58        64         58         80         65
# 2778          [Fire, ]    50       120         53         35        110
# 2779         [Water, ]   130        85         80         85         95
# 2780          [Fire, ]    45        50         45        115         55
# 2781         [Fairy, ]    90        95         95         70         90
# 2782      [Fighting, ]    61        72         57         55         55
# 2783     [Rock, Water]    30        35         30        100         35
# 2784   [Water, Flying]    40        65         95         60         45
# 2785    [Ground, Rock]    81       102         77         85         75
# 2786      [Electric, ]    50       120         53         35        110
# 2787        [Ground, ]    25        20         15        105         55
# 2788      [Bug, Grass]    65        55        115        100         40
# 2789     [Rock, Water]    40        65         95         60         45
# 2790         [Grass, ]    45        67         60         35         50
# 2791       [Psychic, ]    45        67         60         35         50
# 2792   [Water, Flying]    65       125        100         55         70
# 2793        [Normal, ]    70        65         60         90         75
# 2794     [Rock, Water]    60        55         50         40         55
# 2795    [Rock, Ground]    65        45         55         45         70
# 2796         [Fairy, ]    60        50         70         80         80
# 2797     [Rock, Water]    75        80         70         65         75
# 2798  [Grass, Psychic]    30       105         90         25         25
# 2799  [Water, Psychic]    35        85         45         35         35
# 2800         [Water, ]    70        80         50         35         35
# 2801    [Fire, Flying]    55       130        115         50         50
# 2802      [Fighting, ]    80       120        130         55         65
# 2803         [Water, ]    59        63         80         65         80
#
#       Speed_y             type_y
# 0          30    [Grass, Poison]
# 1          65           [Fire, ]
# 2          25       [Bug, Grass]
# 3         110         [Normal, ]
# 4          75          [Water, ]
# 5          35          [Fairy, ]
# 6          50         [Poison, ]
# 7          60    [Grass, Poison]
# 8          35       [Fighting, ]
# 9          30         [Normal, ]
# 10         55         [Poison, ]
# 11        130        [Psychic, ]
# 12        120        [Psychic, ]
# 13         76       [Fighting, ]
# 14         55   [Poison, Flying]
# 15         70    [Water, Poison]
# 16         60          [Water, ]
# 17         80    [Grass, Poison]
# 18         58          [Water, ]
# 19         30       [Bug, Grass]
# 20         45         [Ground, ]
# 21         90           [Fire, ]
# 22         55          [Water, ]
# 23         72         [Normal, ]
# 24         90          [Water, ]
# 25         95     [Ice, Psychic]
# 26         75          [Water, ]
# 27        105      [Bug, Flying]
# 28         55    [Grass, Poison]
# 29         55   [Poison, Flying]
# ...       ...                ...
# 2774       65           [Fire, ]
# 2775       90   [Poison, Flying]
# 2776       60       [Water, Ice]
# 2777       80           [Fire, ]
# 2778       87       [Fighting, ]
# 2779       60       [Water, Ice]
# 2780       95    [Ghost, Poison]
# 2781       70  [Water, Fighting]
# 2782       65         [Poison, ]
# 2783       80    [Ghost, Poison]
# 2784       35         [Poison, ]
# 2785       85   [Poison, Ground]
# 2786       87       [Fighting, ]
# 2787       90        [Psychic, ]
# 2788       60          [Grass, ]
# 2789       35         [Poison, ]
# 2790       63          [Water, ]
# 2791       63          [Water, ]
# 2792       85            [Bug, ]
# 2793       90      [Bug, Poison]
# 2794       45      [Bug, Poison]
# 2795       45          [Water, ]
# 2796      140       [Electric, ]
# 2797       90   [Poison, Flying]
# 2798       50          [Water, ]
# 2799       75   [Normal, Flying]
# 2800       35       [Fighting, ]
# 2801       75          [Water, ]
# 2802       45     [Rock, Ground]
# 2803       58          [Water, ]
#
# [2804 rows x 15 columns]

# %% [markdown]
# # Modelling

# %%
# Train test splitting
X = train.drop(["Winner"], axis=1)
y = train["Winner"]
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

# %%
X_train.head()
# Out:
#       HP_x  Attack_x  Defense_x  Sp. Atk_x  Sp. Def_x  Speed_x  \
# 611     30        45         55         70         55       85
# 530     45        49         49         65         65       45
# 1497    95        70         73         95         90       60
# 49     130        65         60        110         95       65
# 1309    38        41         40         50         65       65
#
#                type_x  HP_y  Attack_y  Defense_y  Sp. Atk_y  Sp. Def_y  \
# 611         [Water, ]    60        65         60        130         75
# 530   [Grass, Poison]    55        81         60         50         70
# 1497        [Fairy, ]    91       134         95        100        100
# 49          [Water, ]    60        40         80         60         45
# 1309         [Fire, ]   105       130        120         45         45
#
#       Speed_y            type_y
# 611       110   [Ghost, Poison]
# 530        97        [Normal, ]
# 1497       80  [Dragon, Flying]
# 49         40  [Grass, Psychic]
# 1309       40    [Ground, Rock]

# %%
# Getting category columns and numerical columns
category_col = ["type_x", "type_y"]
numeric_col = set(X_train.columns) - set(category_col)

# %% [markdown]
# For category columns, we are going to perform **MultiLabelBinarizer**, while for numerical columns, we are going to perform **Standard Scaler**

# %%
category_col = [(i, MultiLabelBinarizer())  for i in category_col]
numeric_col = [([i], StandardScaler())  for i in numeric_col]

# %%
mapper = DataFrameMapper(category_col + numeric_col , df_out=True)

# %%
Z_train = mapper.fit_transform(X_train)
Z_test = mapper.transform(X_test)

# %%
# function to create a dataframe having the training, testing and cross validation score for the models we want
def metric_df(*argv):
    model= {re.sub(r'\([^)]*\)', '', str(i)) : [accuracy_score(y_train, i.fit(Z_train,y_train).predict(Z_train)), 
                                                cross_val_score(i,Z_train,y_train,cv=20).mean(),
                                                accuracy_score(y_test, i.fit(Z_train,y_train).predict(Z_test))]
            for i in argv}
    return pd.DataFrame(model, index=["Accuracy Score Train", "CV Score","Accuracy Score Test"]).T

# %%
metric_df(DecisionTreeClassifier(), ExtraTreeClassifier(), AdaBoostClassifier(n_estimators = 100), 
          BaggingClassifier(n_estimators = 100), GradientBoostingClassifier(n_estimators = 100), 
          RandomForestClassifier(n_estimators = 100), LogisticRegression(solver = "lbfgs"))
# Out:
#                             Accuracy Score Train  CV Score  \
# DecisionTreeClassifier                  1.000000  0.901988
# ExtraTreeClassifier                     1.000000  0.779271
# AdaBoostClassifier                      0.840704  0.810153
# BaggingClassifier                       1.000000  0.933868
# GradientBoostingClassifier              0.943414  0.898650
# RandomForestClassifier                  1.000000  0.891955
# LogisticRegression                      0.863528  0.853508
#
#                             Accuracy Score Test
# DecisionTreeClassifier                 0.900143
# ExtraTreeClassifier                    0.818830
# AdaBoostClassifier                     0.837375
# BaggingClassifier                      0.934379
# GradientBoostingClassifier             0.917261
# RandomForestClassifier                 0.911555
# LogisticRegression                     0.871612

# %% [markdown]
# As we can see, even thought Bagging Classifier is totally ovefit in the training set, it still performs really well on the cross validation and the testing. Hence, we are going to use this model to predict our data

# %%
first_step = pd.merge(test,data,left_on="First_pokemon", right_on="#", how = "left")
second_step = pd.merge(first_step,data,left_on="Second_pokemon", right_on="#", how = "left")
second_step.drop(["First_pokemon","Second_pokemon","#_x", "Name_x", "#_y", "Name_y"], axis = 1, inplace=True)
test_transform = second_step.copy()

# %%
model = BaggingClassifier()

# %%
pipe = make_pipeline(mapper,model)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('dataframemapper',
#                  DataFrameMapper(default=False, df_out=True,
#                                  features=[('type_x',
#                                             MultiLabelBinarizer(classes=None,
#                                                                 sparse_output=False)),
#                                            ('type_y',
#                                             MultiLabelBinarizer(classes=None,
#                                                                 sparse_output=False)),
#                                            (['Sp. Atk_y'],
#                                             StandardScaler(copy=True,
#                                                            with_mean=True,
#                                                            with_std=True)),
#                                            (['Attack_y'],
#                                             StandardScaler(copy=True,
#                                                            with_mean=Tr...
#                                                            with_std=True)),
#                                            (['Speed_x'],
#                                             StandardScaler(copy=True,
#                                                            with_mean=True,
#                                                            with_std=True))],
#                                  input_df=False, sparse=False)),
#                 ('baggingclassifier',
#                  BaggingClassifier(base_estimator=None, bootstrap=True,
#                                    bootstrap_features=False, max_features=1.0,
#                                    max_samples=1.0, n_estimators=10,
#                                    n_jobs=None, oob_score=False,
#                                    random_state=None, verbose=0,
#                                    warm_start=False))],
#          verbose=False)

# %%
predict = pipe.predict(test_transform)

# %%
test["Winner"] = [test["First_pokemon"][index] if values == 1 else test["Second_pokemon"][index] 
                  for index,values in enumerate(predict)]

# %%
test.to_csv("../teams/test_minh.csv")

# %%
import pickle

# %%
pickle.dump(pipe, open("pipe.pkl", "wb"))
pickle.dump(data, open("data.pkl", "wb"))
